# %%
pip install --upgrade imutils
# Out:
# Requirement already up-to-date: imutils in d:\users\yousra\anaconda3\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\users\yousra\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in d:\users\yousra\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the necessary packages
import numpy as np
import argparse
import imutils
import cv2
from PIL import Image
from IPython.display import display, clear_output

# %%
# load the image 
image = cv2.imread("5.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=502x281 at 0x24792257970>

# %%
# convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x24793930490>

# %%
# compute the Scharr gradient magnitude representation of the images
# in both the x and y direction using OpenCV 2.4
ddepth = cv2.cv.CV_32F if imutils.is_cv2() else cv2.CV_32F
gradX = cv2.Sobel(gray, ddepth=ddepth, dx=1, dy=0, ksize=-1)
gradY = cv2.Sobel(gray, ddepth=ddepth, dx=0, dy=1, ksize=-1)

# subtract the y-gradient from the x-gradient
gradient = cv2.subtract(gradX, gradY)
gradient = cv2.convertScaleAbs(gradient)
display(Image.fromarray(gradient))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x24793930190>

# %%
# blur the image
blurred = cv2.blur(gradient, (9, 9))
display(Image.fromarray(blurred))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x24793930CD0>

# %%
# threshold the image
(_, thresh) = cv2.threshold(blurred, 225, 255, cv2.THRESH_BINARY)
display(Image.fromarray(thresh))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x2479224F790>

# %%
# construct a closing kernel and apply it to the thresholded image
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (21, 7))
closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
display(Image.fromarray(closed))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x24792257880>

# %%
# perform a series of erosions
closed = cv2.erode(closed, None, iterations = 4)
display(Image.fromarray(closed))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x24793930DC0>

# %%
# perform a series of dilations
closed = cv2.dilate(closed, None, iterations = 4)
display(Image.fromarray(closed))
# Out:
# <PIL.Image.Image image mode=L size=502x281 at 0x2479382DA30>

# %%
# find the contours in the thresholded image
cnts = cv2.findContours(closed.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)

# %%
# draw a bounding box arounded the detected barcode and display the
# image
cv2.drawContours(image, cnts, -1, (0, 255, 0), 3)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=502x281 at 0x24793930D30>

# %%
#Sort the contours by their area, keeping only the largest one
c = sorted(cnts, key = cv2.contourArea, reverse = True)[0]
# compute the rotated bounding box of the largest contour
rect = cv2.minAreaRect(c)
box = cv2.cv.BoxPoints(rect) if imutils.is_cv2() else cv2.boxPoints(rect)
box = np.int0(box)

# %%
image = cv2.imread("5.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# draw a bounding box arounded the detected barcode and display the image
cv2.drawContours(image, [box], -1, (0, 255, 0), 3)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=502x281 at 0x2479394B4F0>
